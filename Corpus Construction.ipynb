# %% [markdown]
# # Corpus Construction

# %% [markdown]
# ## Set-up

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
fburls = [
    'https://raw.githubusercontent.com/javi-ng/datasets/main/CSCI%20161%20Project%20Datasets/Facebook/CSV%20files/September%2030%20Tottenham.csv',
    'https://raw.githubusercontent.com/javi-ng/datasets/main/CSCI%20161%20Project%20Datasets/Facebook/CSV%20files/September%2030%20Liverpool.csv',
    'https://raw.githubusercontent.com/javi-ng/datasets/main/CSCI%20161%20Project%20Datasets/Facebook/CSV%20files/May%201%20Tottenham%20Post.csv',
    'https://raw.githubusercontent.com/javi-ng/datasets/main/CSCI%20161%20Project%20Datasets/Facebook/CSV%20files/May%201%20Liverpool.csv'
]

yturls = [
    'https://raw.githubusercontent.com/javi-ng/datasets/main/CSCI%20161%20Project%20Datasets/Youtube/Tottenham%20vs%20Liverpool/Sept%2030%20Tottenham%20match%20highlights%20(with%20extended).csv',
    'https://raw.githubusercontent.com/javi-ng/datasets/main/CSCI%20161%20Project%20Datasets/Youtube/Tottenham%20vs%20Liverpool/Sept%2030%20Liverpool%20match%20highlights%20(with%20extended).csv',
    'https://raw.githubusercontent.com/javi-ng/datasets/main/CSCI%20161%20Project%20Datasets/Youtube/Tottenham%20vs%20Liverpool/May%201%20Tottenham%20match%20highlights%20(with%20extended).csv',
    'https://raw.githubusercontent.com/javi-ng/datasets/main/CSCI%20161%20Project%20Datasets/Youtube/Tottenham%20vs%20Liverpool/May%201%20Liverpool%20match%20highlights.csv',
    'https://raw.githubusercontent.com/javi-ng/datasets/main/CSCI%20161%20Project%20Datasets/Youtube/Manchester%20United%20vs%20Wolves/May%2014%20Wolves%20highlights.csv',
    'https://raw.githubusercontent.com/javi-ng/datasets/main/CSCI%20161%20Project%20Datasets/Youtube/Manchester%20United%20vs%20Wolves/May%2014%20Manchester%20United%20highlights.csv',
    'https://raw.githubusercontent.com/javi-ng/datasets/main/CSCI%20161%20Project%20Datasets/Youtube/Manchester%20United%20vs%20Wolves/Aug%2015%20Manchester%20United%20highlights.csv',
    'https://raw.githubusercontent.com/javi-ng/datasets/main/CSCI%20161%20Project%20Datasets/Youtube/Manchester%20United%20vs%20Wolves/Aug%2015%20Wolves%20highlights%20(with%20extended).csv'
]

# %%
def addDF(urls, platform, game, team, bigdf):
  inc = 0
  column = 'message' if platform == 'Facebook' else 'snippet.topLevelComment.snippet.textOriginal' # different column names based on platform extracted from
  separator = ';' if platform == 'Facebook' else ','
  for url in urls:
    temp_df = pd.read_csv(url, sep=separator)
    for ind in temp_df.index:
      bigdf.loc[len(bigdf.index)] = [platform, game[inc], team[inc], temp_df.loc[ind][column]]
    inc = inc + 1

# %% [markdown]
# ## Construction of dataframes

# %% [markdown]
# ### Construction (Facebook)

# %%
fbdf = pd.DataFrame(columns=['Platform', 'Game', 'Team', 'Entry'])

# %%
fbteams = ['Tottenham', 'Liverpool', 'Tottenham', 'Liverpool']
fbgames = [
            'Tottenham vs. Liverpool September 30', 'Tottenham vs. Liverpool September 30',
            'Tottenham vs. Liverpool May 1', 'Tottenham vs. Liverpool May 1'
          ]

# %%
addDF(fburls, 'Facebook', fbgames, fbteams, fbdf)

# %%
fbdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36507 entries, 0 to 36506
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Platform  36507 non-null  object
#  1   Game      36507 non-null  object
#  2   Team      36507 non-null  object
#  3   Entry     34103 non-null  object
# dtypes: object(4)
# memory usage: 1.4+ MB

# %%
fbdf = fbdf.dropna().reset_index(drop=True)
fbdf
# Out:
#        Platform                                  Game       Team  \
# 0      Facebook  Tottenham vs. Liverpool September 30  Tottenham
# 1      Facebook  Tottenham vs. Liverpool September 30  Tottenham
# 2      Facebook  Tottenham vs. Liverpool September 30  Tottenham
# 3      Facebook  Tottenham vs. Liverpool September 30  Tottenham
# 4      Facebook  Tottenham vs. Liverpool September 30  Tottenham
# ...         ...                                   ...        ...
# 34098  Facebook         Tottenham vs. Liverpool May 1  Liverpool
# 34099  Facebook         Tottenham vs. Liverpool May 1  Liverpool
# 34100  Facebook         Tottenham vs. Liverpool May 1  Liverpool
# 34101  Facebook         Tottenham vs. Liverpool May 1  Liverpool
# 34102  Facebook         Tottenham vs. Liverpool May 1  Liverpool
#
#                                                    Entry
# 0      I'd be completely embarrassed to celebrate suc...
# 1      We got lucky, 9 men side and needed an own goa...
# ...

# %%
fbdf.to_csv('full_facebook.csv', index=False)

# %% [markdown]
# ### Construction (Youtube)

# %%
ytdf = pd.DataFrame(columns=['Platform', 'Game', 'Team', 'Entry'])

# %%
ytteams = [
    'Tottenham', 'Liverpool', 'Tottenham', 'Liverpool', 'Wolves', 'Manchester United', 'Manchester United', 'Wolves'
    ]
ytgames = [
    'Tottenham vs. Liverpool September 30', 'Tottenham vs. Liverpool September 30',
    'Tottenham vs. Liverpool May 1', 'Tottenham vs. Liverpool May 1',
    'Manchester United vs. Wolves May 14', 'Manchester United vs. Wolves May 14',
    'Manchester United vs. Wolves August 15', 'Manchester United vs. Wolves August 15'
    ]

# %%
addDF(yturls, 'Youtube', ytgames, ytteams, ytdf)

# %%
ytdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16642 entries, 0 to 16641
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Platform  16642 non-null  object
#  1   Game      16642 non-null  object
#  2   Team      16642 non-null  object
#  3   Entry     16447 non-null  object
# dtypes: object(4)
# memory usage: 650.1+ KB

# %%
ytdf = ytdf.dropna().reset_index(drop=True)
ytdf
# Out:
#       Platform                                    Game       Team  \
# 0      Youtube    Tottenham vs. Liverpool September 30  Tottenham
# 1      Youtube    Tottenham vs. Liverpool September 30  Tottenham
# 2      Youtube    Tottenham vs. Liverpool September 30  Tottenham
# 3      Youtube    Tottenham vs. Liverpool September 30  Tottenham
# 4      Youtube    Tottenham vs. Liverpool September 30  Tottenham
# ...        ...                                     ...        ...
# 16442  Youtube  Manchester United vs. Wolves August 15     Wolves
# 16443  Youtube  Manchester United vs. Wolves August 15     Wolves
# 16444  Youtube  Manchester United vs. Wolves August 15     Wolves
# 16445  Youtube  Manchester United vs. Wolves August 15     Wolves
# 16446  Youtube  Manchester United vs. Wolves August 15     Wolves
#
#                                                    Entry
# 0                   The true man of the match is referee
# 1                                          minimal trofi
# ...

# %%
ytdf.to_csv('full_youtube.csv', index=False)

# %% [markdown]
# ### Corpus Combination

# %%
# checkpoint: csvs are result of above code
ytdf = pd.read_csv('https://raw.githubusercontent.com/javi-ng/datasets/main/CSCI%20161%20Project%20Datasets/youtube_total.csv')
fbdf = pd.read_csv('https://raw.githubusercontent.com/javi-ng/datasets/main/CSCI%20161%20Project%20Datasets/facebook_total.csv')

# %%
ytdf
# Out:
#       Platform                                    Game       Team  \
# 0      Youtube    Tottenham vs. Liverpool September 30  Tottenham
# 1      Youtube    Tottenham vs. Liverpool September 30  Tottenham
# 2      Youtube    Tottenham vs. Liverpool September 30  Tottenham
# 3      Youtube    Tottenham vs. Liverpool September 30  Tottenham
# 4      Youtube    Tottenham vs. Liverpool September 30  Tottenham
# ...        ...                                     ...        ...
# 16442  Youtube  Manchester United vs. Wolves August 15     Wolves
# 16443  Youtube  Manchester United vs. Wolves August 15     Wolves
# 16444  Youtube  Manchester United vs. Wolves August 15     Wolves
# 16445  Youtube  Manchester United vs. Wolves August 15     Wolves
# 16446  Youtube  Manchester United vs. Wolves August 15     Wolves
#
#                                                    Entry
# 0                   The true man of the match is referee
# 1                                          minimal trofi
# ...

# %%
fbdf
# Out:
#        Platform                                  Game       Team  \
# 0      Facebook  Tottenham vs. Liverpool September 30  Tottenham
# 1      Facebook  Tottenham vs. Liverpool September 30  Tottenham
# 2      Facebook  Tottenham vs. Liverpool September 30  Tottenham
# 3      Facebook  Tottenham vs. Liverpool September 30  Tottenham
# 4      Facebook  Tottenham vs. Liverpool September 30  Tottenham
# ...         ...                                   ...        ...
# 34098  Facebook         Tottenham vs. Liverpool May 1  Liverpool
# 34099  Facebook         Tottenham vs. Liverpool May 1  Liverpool
# 34100  Facebook         Tottenham vs. Liverpool May 1  Liverpool
# 34101  Facebook         Tottenham vs. Liverpool May 1  Liverpool
# 34102  Facebook         Tottenham vs. Liverpool May 1  Liverpool
#
#                                                    Entry
# 0      I'd be completely embarrassed to celebrate suc...
# 1      We got lucky, 9 men side and needed an own goa...
# ...

# %%
fulldf = pd.concat([fbdf, ytdf], ignore_index=True)
fulldf
# Out:
#        Platform                                    Game       Team  \
# 0      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 1      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 2      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 3      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 4      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# ...         ...                                     ...        ...
# 50545   Youtube  Manchester United vs. Wolves August 15     Wolves
# 50546   Youtube  Manchester United vs. Wolves August 15     Wolves
# 50547   Youtube  Manchester United vs. Wolves August 15     Wolves
# 50548   Youtube  Manchester United vs. Wolves August 15     Wolves
# 50549   Youtube  Manchester United vs. Wolves August 15     Wolves
#
#                                                    Entry
# 0      I'd be completely embarrassed to celebrate suc...
# ...

# %%
fulldf.to_csv('full_df.csv', index=False)

# %% [markdown]
# # Corpus Cleaning

# %%
# checkpoint
fulldf = pd.read_csv('https://raw.githubusercontent.com/javi-ng/datasets/main/CSCI%20161%20Project%20Datasets/full_df.csv')

# %%
fulldf
# Out:
#        Platform                                    Game       Team  \
# 0      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 1      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 2      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 3      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 4      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# ...         ...                                     ...        ...
# 48802   Youtube  Manchester United vs. Wolves August 15     Wolves
# 48803   Youtube  Manchester United vs. Wolves August 15     Wolves
# 48804   Youtube  Manchester United vs. Wolves August 15     Wolves
# 48805   Youtube  Manchester United vs. Wolves August 15     Wolves
# 48806   Youtube  Manchester United vs. Wolves August 15     Wolves
#
#                                                    Entry
# 0      I'd be completely embarrassed to celebrate suc...
# ...

# %%
# Instatiate NLTK module
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('stopwords')
stopwords = stopwords.words('english')
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def clean_comments(comments):
    # Transform into lowercase
    comments['cleaned_text'] = comments['Entry'].str.lower()

    # Remove usernames, non-alphanumeric characters, and links
    comments['cleaned_text'] = comments['cleaned_text'].str.replace(r'(@[A-Za-z0-9_]+)|([^A-Za-z0-9_ \t])|(\w+:\/\/\S+)', '')

    # Remove single characters
    comments['cleaned_text'] = comments['cleaned_text'].apply(lambda row: ' '.join([word for word in row.split() if len(word) > 1]))

    # Remove stopwords
    comments['cleaned_text'] = comments['cleaned_text'].apply(lambda row: ' '.join([word for word in row.split() if word not in (stopwords)]))

    # Lemmatize verbs
    comments['cleaned_text'] = comments['cleaned_text'].apply(lambda row: ' '.join([lemmatizer.lemmatize(x, 'v') for x in row.split()]))

    # Lemmatize adjectives
    comments['cleaned_text'] = comments['cleaned_text'].apply(lambda row: ' '.join([lemmatizer.lemmatize(x, 'a') for x in row.split()]))

    # Lemmatize nouns
    comments['cleaned_text'] = comments['cleaned_text'].apply(lambda row: ' '.join([lemmatizer.lemmatize(x, 'n') for x in row.split()]))

    # Remove trailing and leading whitespaces
    comments['cleaned_text'] = comments['cleaned_text'].str.replace(r'^\s+|\s+$', '')

    return comments

# %%
clean_df = clean_comments(fulldf)
clean_df
# Out:
# <ipython-input-61-e31792e52471>:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   comments['cleaned_text'] = comments['cleaned_text'].str.replace(r'(@[A-Za-z0-9_]+)|([^A-Za-z0-9_ \t])|(\w+:\/\/\S+)', '')
# <ipython-input-61-e31792e52471>:24: FutureWarning: The default value of regex will change from True to False in a future version.
#   comments['cleaned_text'] = comments['cleaned_text'].str.replace(r'^\s+|\s+$', '')
#        Platform                                    Game       Team  \
# 0      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 1      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 2      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 3      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 4      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# ...         ...                                     ...        ...
# ...

# %%
clean_df = clean_df.drop(labels="Entry", axis=1)

# %%
clean_df
# Out:
#        Platform                                    Game       Team  \
# 0      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 1      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 2      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 3      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 4      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# ...         ...                                     ...        ...
# 48802   Youtube  Manchester United vs. Wolves August 15     Wolves
# 48803   Youtube  Manchester United vs. Wolves August 15     Wolves
# 48804   Youtube  Manchester United vs. Wolves August 15     Wolves
# 48805   Youtube  Manchester United vs. Wolves August 15     Wolves
# 48806   Youtube  Manchester United vs. Wolves August 15     Wolves
#
#                                             cleaned_text
# 0      id completely embarrass celebrate win disallow...
# ...

# %%
clean_df = clean_df.replace(r'^\s*$', np.nan, regex=True)
clean_df
# Out:
#        Platform                                    Game       Team  \
# 0      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 1      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 2      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 3      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 4      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# ...         ...                                     ...        ...
# 48802   Youtube  Manchester United vs. Wolves August 15     Wolves
# 48803   Youtube  Manchester United vs. Wolves August 15     Wolves
# 48804   Youtube  Manchester United vs. Wolves August 15     Wolves
# 48805   Youtube  Manchester United vs. Wolves August 15     Wolves
# 48806   Youtube  Manchester United vs. Wolves August 15     Wolves
#
#                                             cleaned_text
# 0      id completely embarrass celebrate win disallow...
# ...

# %%
clean_df = clean_df.dropna(how='any', axis=0).reset_index(drop=True)
clean_df
# Out:
#        Platform                                    Game       Team  \
# 0      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 1      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 2      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 3      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# 4      Facebook    Tottenham vs. Liverpool September 30  Tottenham
# ...         ...                                     ...        ...
# 45523   Youtube  Manchester United vs. Wolves August 15     Wolves
# 45524   Youtube  Manchester United vs. Wolves August 15     Wolves
# 45525   Youtube  Manchester United vs. Wolves August 15     Wolves
# 45526   Youtube  Manchester United vs. Wolves August 15     Wolves
# 45527   Youtube  Manchester United vs. Wolves August 15     Wolves
#
#                                             cleaned_text
# 0      id completely embarrass celebrate win disallow...
# ...

# %%
clean_df.to_csv('clean_df.csv', index=False)
